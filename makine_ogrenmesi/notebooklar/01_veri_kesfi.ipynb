# %% [markdown]
# # 01 - Veri Kesfi
#
# - Amac: Pima Indians Diabetes veri setinin temel yapisini ve dagilimini incelemek.
# - Not: Bu notebook iskelet amaclidir, ayrintili icerik sonraki gorevlerde doldurulacaktir.

# %% [markdown]
# ## 0. Kurulum ve Import Ayarlari
# - Proje kokunu sys.path icine ekler.
# - Notebooklar arasi tutarli calisma icin ortak baslangic hucresidir.

# %%
from pathlib import Path
import sys

proje_kok = Path.cwd().resolve()
while proje_kok.name != 'diyabet_risk_tahmini' and proje_kok.parent != proje_kok:
    proje_kok = proje_kok.parent

if str(proje_kok) not in sys.path:
    sys.path.insert(0, str(proje_kok))

print('Proje koku:', proje_kok)

# %% [markdown]
# ## 1. Veri yukleme
# - Bu bolumde analiz adimlari yazilacaktir.
# - Bulgular kisa ve takip edilebilir sekilde not edilecektir.

# %%
# TODO: Bu bolum kodlari sonraki asamada eklenecek.

# %% [markdown]
# ## 2. Temel ozet istatistikler
# - Bu bolumde analiz adimlari yazilacaktir.
# - Bulgular kisa ve takip edilebilir sekilde not edilecektir.

# %%
# TODO: Bu bolum kodlari sonraki asamada eklenecek.

# %% [markdown]
# ## 3. 0 deger ve eksik deger incelemesi
# - Bu bolumde analiz adimlari yazilacaktir.
# - Bulgular kisa ve takip edilebilir sekilde not edilecektir.

# %%
# TODO: Bu bolum kodlari sonraki asamada eklenecek.

# %% [markdown]
# ## 4. Hedef degisken dagilimi
# - Bu bolumde analiz adimlari yazilacaktir.
# - Bulgular kisa ve takip edilebilir sekilde not edilecektir.

# %%
# TODO: Bu bolum kodlari sonraki asamada eklenecek.

# %% [markdown]
# ## 5. Ozellik iliskileri ve notlar
# - Bu bolumde analiz adimlari yazilacaktir.
# - Bulgular kisa ve takip edilebilir sekilde not edilecektir.

# %%
# TODO: Bu bolum kodlari sonraki asamada eklenecek.
